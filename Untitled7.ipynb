# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
# Load your dataset (adjust the path if needed)
csv_path = "Online Sales Data.csv"
df = pd.read_csv(csv_path)
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['transaction_id', 'date', 'product_category', 'product_name',
#        'units_sold', 'unit_price', 'total_revenue', 'region',
#        'payment_method'],
#       dtype='object')

# %%
import sqlite3
conn = sqlite3.connect("sales_data.db")
df.to_sql("sales", conn, if_exists="replace", index=False)
print("Data has been written to the SQLite database.")
# Out:
# Data has been written to the SQLite database.

# %%
import pandas as pd
df = pd.read_csv("Online Sales Data.csv")
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
# Show actual column names
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
import sqlite3
conn = sqlite3.connect("sales_data.db")
df.to_sql("sales", conn, if_exists="replace", index=False)
# Out:
# 240

# %%
df.columns.tolist()
# Out:
# ['Transaction ID',
#  'Date',
#  'Product Category',
#  'Product Name',
#  'Units Sold',
#  'Unit Price',
#  'Total Revenue',
#  'Region',
#  'Payment Method']

# %%
['Order ID', 'Product Name', 'Quantity', 'Price', ...]
# Out:
# ['Order ID', 'Product Name', 'Quantity', 'Price', Ellipsis]

# %%
['Order ID', 'Product Name', 'Quantity Ordered', 'Price Each']
# Out:
# ['Order ID', 'Product Name', 'Quantity Ordered', 'Price Each']

# %%
import sqlite3

conn = sqlite3.connect("sales_data.db")

# Get table column info
cursor = conn.execute("PRAGMA table_info(sales);")
columns = cursor.fetchall()
columns
# Out:
# [(0, 'Transaction ID', 'INTEGER', 0, None, 0),
#  (1, 'Date', 'TEXT', 0, None, 0),
#  (2, 'Product Category', 'TEXT', 0, None, 0),
#  (3, 'Product Name', 'TEXT', 0, None, 0),
#  (4, 'Units Sold', 'INTEGER', 0, None, 0),
#  (5, 'Unit Price', 'REAL', 0, None, 0),
#  (6, 'Total Revenue', 'REAL', 0, None, 0),
#  (7, 'Region', 'TEXT', 0, None, 0),
#  (8, 'Payment Method', 'TEXT', 0, None, 0)]
